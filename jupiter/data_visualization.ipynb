# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import ast

# %%
df = pd.read_csv("../data/processed/cleaned_data.csv")
df.head()
# Out:
#                     Title                                Genres  Year  Rating  \
# 0  Mission: Impossible II   ['Adventure', 'Thriller', 'Action']  2000     6.1
# 1               Gladiator      ['Adventure', 'Drama', 'Action']  2000     8.2
# 2               Cast Away                ['Adventure', 'Drama']  2000     7.7
# 3         What Women Want                 ['Romance', 'Comedy']  2000     6.4
# 4                Dinosaur  ['Adventure', 'Animation', 'Family']  2000     6.5
#
#    Vote_Count                            Production_Countries  $Worldwide  \
# 0        6741                    ['United States of America']   546388108
# 1       19032  ['United Kingdom', 'United States of America']   460583960
# 2       11403                    ['United States of America']   429632142
# 3        3944  ['United Kingdom', 'United States of America']   374111707
# 4        2530                    ['United States of America']   349822765
#
#    $Domestic  Domestic %   $Foreign  Foreign %
# 0  215409889        39.4  330978219       60.6
# 1  187705427        40.8  272878533       59.2
# 2  233632142        54.4  196000000       45.6
# 3  182811707        48.9  191300000       51.1
# 4  137748063        39.4  212074702       60.6

# %%
# tổng doanh thu phòng vé qua các năm
df.groupby("Year")["$Worldwide"].sum().plot(kind="line", figsize=(10, 5), title="Tổng doanh thu phòng vé qua các năm")
plt.show()

# %%
# phân phối tỉ lệ phần trăm doanh thu trong nước và nước ngoài
sns.boxplot(data = df[["Domestic %", "Foreign %"]], palette = "pastel")
plt.title("Phân phối tỉ lệ phần trăm doanh thu trong nước và nước ngoài")
plt.ylabel("Phần trăm")
plt.show()

# %%
# Phim có doanh thu cao nhất
df_top_worldwide = df.sort_values(by="$Worldwide", ascending=False).head(10)
df_top_worldwide
# Out:
#                                            Title  \
# 3663                           Avengers: Endgame
# 1753                                      Avatar
# 4229                    Avatar: The Way of Water
# 2893  Star Wars: Episode VII - The Force Awakens
# 3473                      Avengers: Infinity War
# 4041                     Spider-Man: No Way Home
# 4610                                Inside Out 2
# 2894                              Jurassic World
# 3664                               The Lion King
# 2323                                The Avengers
#
#                                                  Genres  Year  Rating  \
# 3663         ['Adventure', 'Science Fiction', 'Action']  2019     8.2
# 1753  ['Science Fiction', 'Adventure', 'Fantasy', 'A...  2009     7.6
# 4229         ['Adventure', 'Science Fiction', 'Action']  2022     7.6
# 2893         ['Adventure', 'Science Fiction', 'Action']  2015     7.3
# 3473         ['Adventure', 'Science Fiction', 'Action']  2018     8.2
# 4041         ['Adventure', 'Science Fiction', 'Action']  2021     8.0
# 4610     ['Adventure', 'Comedy', 'Animation', 'Family']  2024     7.6
# 2894  ['Adventure', 'Thriller', 'Science Fiction', '...  2015     6.7
# 3664      ['Adventure', 'Drama', 'Animation', 'Family']  2019     7.1
# 2323         ['Adventure', 'Science Fiction', 'Action']  2012     7.7
#
#       Vote_Count                            Production_Countries  $Worldwide  \
# 3663       25780                    ['United States of America']  2799439100
# 1753       31654  ['United Kingdom', 'United States of America']  2743577587
# 4229       12052                    ['United States of America']  2320250281
# 2893       19411                    ['United States of America']  2068223624
# 3473       29914                    ['United States of America']  2048359754
# 4041       20275                    ['United States of America']  1910982770
# 4610        5141                    ['United States of America']  1698772985
# 2894       20370                    ['United States of America']  1670400637
# 3664       10058                    ['United States of America']  1656943394
# 2323       30942                    ['United States of America']  1518812988
#
#       $Domestic  Domestic %    $Foreign  Foreign %
# 3663  858373000        30.7  1941066100       69.3
# 1753  749766139        27.3  1993811448       72.7
# 4229  684075767        29.5  1636174514       70.5
# 2893  936662225        45.3  1131561399       54.7
# 3473  678815482        33.1  1369544272       66.9
# 4041  804793477        42.1  1106189293       57.9
# 4610  652980194        38.4  1045792791       61.6
# 2894  652270625        39.0  1018130012       61.0
# 3664  543638043        32.8  1113305351       67.2
# 2323  623357910        41.0   895455078       59.0

# %%
sns.barplot(x="$Worldwide", y="Title", data=df_top_worldwide, palette="crest")
plt.title("Top 10 phim có doanh thu toàn cầu cao nhất")
plt.show()
# Out:
# C:\Users\zigdo\AppData\Local\Temp\ipykernel_13536\112156978.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="$Worldwide", y="Title", data=df_top_worldwide, palette="crest")

# %%
# Phim có doanh thu phòng vé trong nước cao nhất
df_top_domestic = df.sort_values(by="$Domestic", ascending=False).head(10)
df_top_domestic
# Out:
#                                            Title  \
# 2893  Star Wars: Episode VII - The Force Awakens
# 3663                           Avengers: Endgame
# 4041                     Spider-Man: No Way Home
# 1753                                      Avatar
# 4230                           Top Gun: Maverick
# 3474                               Black Panther
# 4229                    Avatar: The Way of Water
# 3473                      Avengers: Infinity War
# 4610                                Inside Out 2
# 2894                              Jurassic World
#
#                                                  Genres  Year  Rating  \
# 2893         ['Adventure', 'Science Fiction', 'Action']  2015     7.3
# 3663         ['Adventure', 'Science Fiction', 'Action']  2019     8.2
# 4041         ['Adventure', 'Science Fiction', 'Action']  2021     8.0
# 1753  ['Science Fiction', 'Adventure', 'Fantasy', 'A...  2009     7.6
# 4230                                ['Drama', 'Action']  2022     8.2
# 3474         ['Adventure', 'Science Fiction', 'Action']  2018     7.4
# 4229         ['Adventure', 'Science Fiction', 'Action']  2022     7.6
# 3473         ['Adventure', 'Science Fiction', 'Action']  2018     8.2
# 4610     ['Adventure', 'Comedy', 'Animation', 'Family']  2024     7.6
# 2894  ['Adventure', 'Thriller', 'Science Fiction', '...  2015     6.7
#
#       Vote_Count                            Production_Countries  $Worldwide  \
# 2893       19411                    ['United States of America']  2068223624
# 3663       25780                    ['United States of America']  2799439100
# 4041       20275                    ['United States of America']  1910982770
# 1753       31654  ['United Kingdom', 'United States of America']  2743577587
# 4230        9343                    ['United States of America']  1495696292
# 3474       22231                    ['United States of America']  1346913161
# 4229       12052                    ['United States of America']  2320250281
# 3473       29914                    ['United States of America']  2048359754
# 4610        5141                    ['United States of America']  1698772985
# 2894       20370                    ['United States of America']  1670400637
#
#       $Domestic  Domestic %    $Foreign  Foreign %
# 2893  936662225        45.3  1131561399       54.7
# 3663  858373000        30.7  1941066100       69.3
# 4041  804793477        42.1  1106189293       57.9
# 1753  749766139        27.3  1993811448       72.7
# 4230  718732821        48.1   776963471       51.9
# 3474  700059566        52.0   646853595       48.0
# 4229  684075767        29.5  1636174514       70.5
# 3473  678815482        33.1  1369544272       66.9
# 4610  652980194        38.4  1045792791       61.6
# 2894  652270625        39.0  1018130012       61.0

# %%
sns.barplot(x="$Domestic", y="Title", data=df_top_domestic, palette="icefire")
plt.title("Top 10 phim có doanh thu trong nước cao nhất")
plt.show()
# Out:
# C:\Users\zigdo\AppData\Local\Temp\ipykernel_13536\3927385025.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="$Domestic", y="Title", data=df_top_domestic, palette="icefire")

# %%
# Phim có nhiều lượt vote nhất
df_top_vote = df.sort_values(by="Vote_Count", ascending=False).head(10)
df_top_vote
# Out:
#                                       Title  \
# 1950                              Inception
# 2709                           Interstellar
# 1556                        The Dark Knight
# 1753                                 Avatar
# 3095                               Deadpool
# 2323                           The Avengers
# 3473                 Avengers: Infinity War
# 2702                Guardians of the Galaxy
# 194   Harry Potter and the Sorcerer's Stone
# 1563                               Iron Man
#
#                                                  Genres  Year  Rating  \
# 1950         ['Adventure', 'Science Fiction', 'Action']  2010     8.4
# 2709          ['Adventure', 'Drama', 'Science Fiction']  2014     8.4
# 1556           ['Crime', 'Drama', 'Action', 'Thriller']  2008     8.5
# 1753  ['Science Fiction', 'Adventure', 'Fantasy', 'A...  2009     7.6
# 3095                  ['Adventure', 'Comedy', 'Action']  2016     7.6
# 2323         ['Adventure', 'Science Fiction', 'Action']  2012     7.7
# 3473         ['Adventure', 'Science Fiction', 'Action']  2018     8.2
# 2702         ['Adventure', 'Science Fiction', 'Action']  2014     7.9
# 194                            ['Adventure', 'Fantasy']  2001     7.9
# 1563         ['Adventure', 'Science Fiction', 'Action']  2008     7.6
#
#       Vote_Count                            Production_Countries  $Worldwide  \
# 1950       36753  ['United Kingdom', 'United States of America']   828258695
# 2709       35934  ['United Kingdom', 'United States of America']   681070397
# 1556       33108  ['United Kingdom', 'United States of America']  1003845358
# 1753       31654  ['United Kingdom', 'United States of America']  2743577587
# 3095       31141                    ['United States of America']   782612155
# 2323       30942                    ['United States of America']  1518812988
# 3473       29914                    ['United States of America']  2048359754
# 2702       28085                    ['United States of America']   772776600
# 194        27607  ['United Kingdom', 'United States of America']   974755371
# 1563       26470                    ['United States of America']   585366247
#
#       $Domestic  Domestic %    $Foreign  Foreign %
# 1950  292576195        35.3   535682500       64.7
# 2709  188020017        27.6   493050380       72.4
# 1556  533345358        53.1   470500000       46.9
# 1753  749766139        27.3  1993811448       72.7
# 3095  363070709        46.4   419541446       53.6
# 2323  623357910        41.0   895455078       59.0
# 3473  678815482        33.1  1369544272       66.9
# 2702  333176600        43.1   439600000       56.9
# 194   317575550        32.6   657179821       67.4
# 1563  318604126        54.4   266762121       45.6

# %%
sns.barplot(x="Vote_Count", y="Title", data=df_top_vote, palette="magma")
plt.title("Top 10 phim có lượt vote nhiều nhất")
plt.show()
# Out:
# C:\Users\zigdo\AppData\Local\Temp\ipykernel_13536\936448163.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="Vote_Count", y="Title", data=df_top_vote, palette="magma")

# %%
# Top 10 phim có điểm cao nhất
df_top_rate = df.sort_values(by="Rating", ascending=False).head(10)
df_top_rate
# Out:
#                                                   Title  \
# 4786         Attack on Titan the Movie: The Last Attack
# 3973                       Break the Silence: The Movie
# 4749                            The Enchanted Tinderbox
# 4304  BTS Permission to Dance on Stage - Seoul: Live...
# 4754                                     I'm Still Here
# 4776  Uma Musume: Pretty Derby - Beginning of a New Era
# 4340                                          Godfather
# 4605                            Pretty Cure All Stars F
# 4507                     Renaissance: A Film by Beyoncé
# 4208                           Kaguya-sama: Love Is War
#
#                                                  Genres  Year  Rating  \
# 4786                   ['Drama', 'Animation', 'Action']  2024     9.7
# 3973                           ['Documentary', 'Music']  2020     9.0
# 4749        ['Adventure', 'Drama', 'Fantasy', 'Family']  2024     9.0
# 4304                           ['Documentary', 'Music']  2022     8.9
# 4754                               ['History', 'Drama']  2024     8.9
# 4776        ['Drama', 'Comedy', 'Animation', 'Fantasy']  2024     8.7
# 4340                                 ['Crime', 'Drama']  2022     8.7
# 4605  ['Adventure', 'Action', 'Animation', 'Fantasy'...  2023     8.6
# 4507                           ['Documentary', 'Music']  2023     8.6
# 4208                              ['Romance', 'Comedy']  2021     8.5
#
#       Vote_Count          Production_Countries  $Worldwide  $Domestic  \
# 4786           3                     ['Japan']     7796800          0
# 3973         182               ['South Korea']     8954345          0
# 4749           2                    ['Russia']    11676459          0
# 4304         118               ['South Korea']    32600000    6840000
# 4754         103          ['France', 'Brazil']    11100000          0
# 4776           3                     ['Japan']     8551637          0
# 4340       20799  ['United States of America']    18737287          0
# 4605           5                     ['Japan']     8557763          0
# 4507          27  ['United States of America']    43989684   33889684
# 4208          13                     ['Japan']     8794981          0
#
#       Domestic %  $Foreign  Foreign %
# 4786         0.0   7796800      100.0
# 3973         0.0   8954345      100.0
# 4749         0.0  11676459      100.0
# 4304        21.0  25760000       79.0
# 4754         0.0  11100000      100.0
# 4776         0.0   8551637      100.0
# 4340         0.0  18737287      100.0
# 4605         0.0   8557763      100.0
# 4507        77.0  10100000       23.0
# 4208         0.0   8794981      100.0

# %%
sns.barplot(x="Rating", y="Title", data=df_top_rate, palette="Set1")
plt.title("Top 10 phim có điểm đánh giá cao nhất")
plt.show()
# Out:
# C:\Users\zigdo\AppData\Local\Temp\ipykernel_13536\3929507068.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="Rating", y="Title", data=df_top_rate, palette="Set1")

# %%
# chuyển str -> list
df['Genres'] = df['Genres'].apply(ast.literal_eval)

# %%
genre_counts = df['Genres'].explode().value_counts()
genre_counts
# Out:
# Genres
# Drama              1999
# Comedy             1903
# Action             1383
# Adventure          1060
# Thriller           1059
# Romance             841
# Crime               699
# Family              691
# Fantasy             634
# Science Fiction     513
# Animation           493
# Horror              435
# Mystery             430
# History             293
# Music               148
# War                 144
# Documentary          72
# Western              34
# TV Movie              6
# Name: count, dtype: int64

# %%
total = genre_counts.sum()
total
# Out:
# np.int64(12837)

# %%
# phân phối thể loại

min_percent = 0.01  # xuất hiện dưới 1% = Other

rare_genres = genre_counts[genre_counts / total < min_percent]
popular_genres = genre_counts[genre_counts / total >= min_percent]

genre_counts_final = popular_genres.copy()
genre_counts_final['Other'] = rare_genres.sum()

genre_counts_final = genre_counts_final.sort_values(ascending=False) # Sắp xếp giảm dần
genre_counts_final
# Out:
# Genres
# Drama              1999
# Comedy             1903
# Action             1383
# Adventure          1060
# Thriller           1059
# Romance             841
# Crime               699
# Family              691
# Fantasy             634
# Science Fiction     513
# Animation           493
# Horror              435
# Mystery             430
# History             293
# Music               148
# War                 144
# Other               112
# Name: count, dtype: int64

# %%
plt.figure(figsize=(8, 8))

plt.pie(
    genre_counts_final,
    labels=genre_counts_final.index,
    autopct='%1.1f%%',
    startangle=140,
)
plt.title('Phân bổ thể loại')
plt.show()

# %%
# Heatmap
numeric_columns = ["$Worldwide", "$Domestic", "Domestic %", "$Foreign", "Foreign %", "Rating", "Vote_Count"]
df_numeric = df[numeric_columns]
f, ax = plt.subplots(figsize=(10, 6))
sns.heatmap(df_numeric.corr(), annot=True, cmap="coolwarm", fmt=".2f", linewidths=.5, ax=ax)
plt.show()
